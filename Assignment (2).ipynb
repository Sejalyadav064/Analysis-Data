# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches =pd.read_csv("matches.csv")
deliveries =pd.read_csv("deliveries.csv")
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
team_wins= matches["winner"].value_counts().reset_index()
team_wins.columns=["team","total wins"]
team_wins
# Out:
#                            team  total wins
# 0                Mumbai Indians         109
# 1           Chennai Super Kings         100
# 2         Kolkata Knight Riders          92
# 3   Royal Challengers Bangalore          84
# 4               Kings XI Punjab          82
# 5              Rajasthan Royals          75
# 6              Delhi Daredevils          67
# 7           Sunrisers Hyderabad          58
# 8               Deccan Chargers          29
# 9                 Gujarat Lions          13
# 10                Pune Warriors          12
# 11       Rising Pune Supergiant          10
# 12               Delhi Capitals          10
# 13         Kochi Tuskers Kerala           6
# 14      Rising Pune Supergiants           5

# %%
# 1.Matches won by maximum margins of runs
matches.loc[matches['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
# INSIGHTS-
#* this match had the highest run margin victory in IPL history.
#* It shows dominance in batting + bowleing performance

# %%
# 2.Match won by maximum wickets
matches.loc[matches['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
# # INSIGHTS-
# *Winning by 10 wickets shows complete dominance while chasing.

# %%
# # 3.Matches won by minimum margins of runs
matches[matches['win_by_runs']>0].sort_values(by='win_by_runs').head(1)
# Out:
#         id  season       city      date           team1                team2  \
# 755  11415    2019  Hyderabad  12/05/19  Mumbai Indians  Chennai Super Kings
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 755  Mumbai Indians           bat  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match  \
# 755            1               0       JJ Bumrah
#
#                                   venue      umpire1    umpire2      umpire3
# 755  Rajiv Gandhi Intl. Cricket Stadium  Nitin Menon  Ian Gould  Nigel Llong

# %%
# #INSIGHTS-
# These are nail-biting matches that increase audience engagement

# %%
 # 4.Matches won by minimum wickets
matches[matches['win_by_wickets']>0].sort_values(by='win_by_wickets').head(1)
# Out:
#        id  season       city      date           team1                team2  \
# 642  7900    2018  Hyderabad  12/04/18  Mumbai Indians  Sunrisers Hyderabad
#
#              toss_winner toss_decision  result  dl_applied  \
# 642  Sunrisers Hyderabad         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 642  Sunrisers Hyderabad            0               1     Rashid Khan
#
#                                          venue   umpire1      umpire2  \
# 642  Rajiv Gandhi International Stadium, Uppal  O Nandan  Nigel Llong
#
#              umpire3
# 642  Vineet Kulkarni

# %%
# #INSIGHTS-
# * Close wicket wins create high excitement

# %%
# 5.Matches where D/L method was applied
matches['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    737
# 1     19
# Name: count, dtype: int64

# %%
# #INSIGHTS-
# Shows how many matches were affected by rain.

# %%
# 6.Number of matches held in each city.
city_matches= matches['city'].value_counts()
plt.figure(figsize=(10,6))
city_matches.plot(kind='line', color= 'yellow')
plt.title('matches in each city')
plt.show()

# %%
# #INSIGHTS-
# *Cities like Mumbai,Kolkata,and Banglore host more matches---> higher engagement markets.

# %%
#7. Matches won by each team 
team_wins=matches['winner'].value_counts()
plt.figure(figsize=(10,6))
team_wins.plot(kind='line',marker='o', color='pink')
plt.title('matches won by each team')
plt.show()

# %%
# #INSIGHTS-
# *Team with consistent performance build stronger fan bases.

# %%
# 8.Matches held every season
season_matches =matches['season'].value_counts().sort_index()
season_matches.plot(kind='barh',color='purple')
plt.title("matches per season")
plt.show()

# %%
# #INSIGHTS-
# *IPL expanded over time with more matches in later seasons.

# %%
# 9.Top 10 Players with most man of the match
top_mom =matches['player_of_match'].value_counts().head(10)
top_mom.plot(kind='pie', color='k')
plt.title("top 10 man of the match winners")
plt.show()

# %%
# #INSIGHTS-
# * These Players significantly impact match outcomes and brand value.

# %%
# 10.Does winning toss mean winning match?
toss_win_match_win=matches[matches['toss_winner']==matches['winner']]
percentage =len(toss_win_match_win)/len (matches)*100
percentage
# Out:
# 51.98412698412699

# %%
# #INSIGHTS-
# *If percentage is around 50-55%,toss advantage is moderate, not guaranteed.

# %%
#11.Toss decision Distribution
matches['toss_decision'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('toss_decision distribution')
plt.show()

# %%
# #INSIGHTS-
# *Captains prefer chasing in modern IPL seasons.

# %%
# 12.D/L applied per season
import pandas as pd
import matplotlib.pyplot as plt
dl_season= matches[matches['dl_applied']==1]['season'].value_counts().sort_index()
dl_season.plot(kind='pie')
plt.title('D/L matches per season')
plt.show()

# %%
# 13.Diffrent match results
matches['result'].value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
# #INSIGHTS-
# Most matches end normally;very few ties or no results.

# %%
# 14.How many times each team won toss.
matches['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
# 15.Best venue for defending & chasing.
Defending=matches[matches['win_by_runs']>0]['venue'].value_counts().head()
chasing=matches[matches['win_by_wickets']>0]['venue'].value_counts().head()
print(chasing)
print(Defending)
# Out:
# venue
# Eden Gardens              45
# M Chinnaswamy Stadium     40
# Wankhede Stadium          37
# Feroz Shah Kotla          33
# Sawai Mansingh Stadium    32
# Name: count, dtype: int64
# venue
# Wankhede Stadium                   35
# Feroz Shah Kotla                   33
# Eden Gardens                       32
# MA Chidambaram Stadium, Chepauk    30
# M Chinnaswamy Stadium              30
# Name: count, dtype: int64

# %%
# #INSIGHTS-
# *Some stadiums support defending due to pitch conditions

# %%
# 16.Best defending and chasing teams
best_defending=matches[matches['win_by_runs']>0]['winner'].value_counts().head()
best_chasing=matches[matches['win_by_wickets']>0]['winner'].value_counts().head()
print(best_defending)
print(best_chasing)
# Out:
# winner
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Name: count, dtype: int64
# winner
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Name: count, dtype: int64

# %%
# 17.Matches played in each stadium
matches['venue'].value_counts().head()
# Out:
# venue
# Eden Gardens                                 77
# M Chinnaswamy Stadium                        73
# Wankhede Stadium                             73
# Feroz Shah Kotla                             67
# Rajiv Gandhi International Stadium, Uppal    56
# Name: count, dtype: int64
